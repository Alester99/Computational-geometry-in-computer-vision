# %%
import numpy as np

sup_grid ={0: [['8', '1', '5', '4', '3', '9', '6', '2', '7'],
       ['3', '6', '2', '7', '5', '1', '4', '9', '8'],
       ['4', '7', '9', '2', '6', '8', '5', '1', '3'],
       ['9', '2', '4', '6', '8', '7', '1', '3', '5'],
       ['1', '5', '7', '3', '9', '2', '8', '6', '4'],
       ['6', '3', '8', '1', '4', '5', '2', '7', '9'],
       ['7', '4', '6', '5', '2', '3', '9', '8', '1'],
       ['2', '8', '3', '9', '1', '4', '7', '5', '6'],
       ['5', '9', '1', '8', '7', '6', '3', '4', '2']], 
 2: [['8', '1', '5', '4', '3', '9', '6', '2', '7'],
       ['3', '6', '2', '6', '5', '1', '4', '9', '8'],
       ['4', '7', '9', '2', '6', '8', '5', '1', '3'],
       ['9', '2', '4', '6', '8', '7', '1', '3', '5'],
       ['1', '5', '7', '3', '9', '2', '8', '6', '4'],
       ['6', '3', '8', '1', '4', '5', '2', '7', '9'],
       ['7', '4', '6', '5', '2', '3', '9', '8', '1'],
       ['2', '8', '3', '9', '1', '4', '7', '5', '6'],
       ['5', '9', '1', '8', '7', '6', '3', '4', '2']]}
grid_test = [['8', '1', '5', '4', '3', '9', '6', '2', '7'],
       ['3', '6', '2', '7', '5', '1', '4', '9', '8'],
       ['4', '7', '9', '2', '6', '8', '5', '1', '3'],
       ['9', '2', '4', '6', '8', '7', '1', '3', '5'],
       ['1', '5', '7', '3', '9', '2', '8', '6', '4'],
       ['6', '3', '8', '1', '4', '5', '2', '7', '9'],
       ['7', '4', '6', '5', '2', '3', '9', '8', '1'],
       ['2', '8', '3', '9', '1', '4', '7', '5', '6'],
       ['5', '9', '1', '8', '7', '6', '3', '4', '2']]

#all([grid_test != sup_grid[k] for k in sup_grid.keys()])
any([grid_test != sup_grid[k] for k in sup_grid.keys()])
# Out:
# True
